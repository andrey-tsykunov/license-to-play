# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from agents.extensions.visualization import draw_graph

from openai_agent.multi_language_agent import create_agent

agent = create_agent()
draw_graph(agent)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 from openai_agent.multi_language_agent import create_agent
#       4 agent = create_agent()
# ----> 5 draw_graph(agent)
#
# File ~/dev/license-to-play/.venv/lib/python3.13/site-packages/agents/extensions/visualization.py:159, in draw_graph(agent, filename)
#     148 def draw_graph(agent: Agent, filename: str | None = None) -> graphviz.Source:
#     149     """
#     150     Draws the graph for the given agent and optionally saves it as a PNG file.
#     151
#    (...)    157         graphviz.Source: The graphviz Source object representing the graph.
#     158     """
# --> 159     dot_code = get_main_graph(agent)
#     160     graph = graphviz.Source(dot_code)
#     162     if filename:
#
# File ~/dev/license-to-play/.venv/lib/python3.13/site-packages/agents/extensions/visualization.py:29, in get_main_graph(agent)
#      20 parts = [
#      21     """
#      22 digraph G {
#    (...)     26 """
#      27 ]
#      28 parts.append(get_all_nodes(agent))
# ---> 29 parts.append(get_all_edges(agent))
#      30 parts.append("}")
#      31 return "".join(parts)
#
# File ~/dev/license-to-play/.venv/lib/python3.13/site-packages/agents/extensions/visualization.py:140, in get_all_edges(agent, parent, visited)
#     137     if isinstance(handoff, Agent):
#     138         parts.append(f"""
#     139         "{agent.name}" -> "{handoff.name}";""")
# --> 140         parts.append(get_all_edges(handoff, agent, visited))
#     142 if not agent.handoffs and not isinstance(agent, Tool):  # type: ignore
#     143     parts.append(f'"{agent.name}" -> "__end__";')
#
# File ~/dev/license-to-play/.venv/lib/python3.13/site-packages/agents/extensions/visualization.py:142, in get_all_edges(agent, parent, visited)
#     138         parts.append(f"""
#     139         "{agent.name}" -> "{handoff.name}";""")
#     140         parts.append(get_all_edges(handoff, agent, visited))
# --> 142 if not agent.handoffs and not isinstance(agent, Tool):  # type: ignore
#     143     parts.append(f'"{agent.name}" -> "__end__";')
#     145 return "".join(parts)
#
# File ~/.local/share/uv/python/cpython-3.13.9-macos-aarch64-none/lib/python3.13/typing.py:1787, in _UnionGenericAlias.__instancecheck__(self, obj)
#    1785 def __instancecheck__(self, obj):
#    1786     for arg in self.__args__:
# -> 1787         if isinstance(obj, arg):
#    1788             return True
#    1789     return False
#
# File ~/.local/share/uv/python/cpython-3.13.9-macos-aarch64-none/lib/python3.13/typing.py:1375, in _BaseGenericAlias.__instancecheck__(self, obj)
#    1374 def __instancecheck__(self, obj):
# -> 1375     return self.__subclasscheck__(type(obj))
#
# File ~/.local/share/uv/python/cpython-3.13.9-macos-aarch64-none/lib/python3.13/typing.py:1378, in _BaseGenericAlias.__subclasscheck__(self, cls)
#    1377 def __subclasscheck__(self, cls):
# -> 1378     raise TypeError("Subscripted generics cannot be used with"
#    1379                     " class and instance checks")
#
# TypeError: Subscripted generics cannot be used with class and instance checks

# %%
from agents import Runner

result = await Runner.run(agent, input="Hola, ¿cómo estás?")

print(result.final_output)
# Out:
# Te paso con un agente de habla hispana para ayudarte. ¿En qué puedo asistirte hoy?

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 draw_graph(agent)
#
# File ~/dev/license-to-play/.venv/lib/python3.13/site-packages/agents/extensions/visualization.py:159, in draw_graph(agent, filename)
#     148 def draw_graph(agent: Agent, filename: str | None = None) -> graphviz.Source:
#     149     """
#     150     Draws the graph for the given agent and optionally saves it as a PNG file.
#     151
#    (...)    157         graphviz.Source: The graphviz Source object representing the graph.
#     158     """
# --> 159     dot_code = get_main_graph(agent)
#     160     graph = graphviz.Source(dot_code)
#     162     if filename:
#
# File ~/dev/license-to-play/.venv/lib/python3.13/site-packages/agents/extensions/visualization.py:29, in get_main_graph(agent)
#      20 parts = [
#      21     """
#      22 digraph G {
#    (...)     26 """
#      27 ]
#      28 parts.append(get_all_nodes(agent))
# ---> 29 parts.append(get_all_edges(agent))
#      30 parts.append("}")
#      31 return "".join(parts)
#
# File ~/dev/license-to-play/.venv/lib/python3.13/site-packages/agents/extensions/visualization.py:140, in get_all_edges(agent, parent, visited)
#     137     if isinstance(handoff, Agent):
#     138         parts.append(f"""
#     139         "{agent.name}" -> "{handoff.name}";""")
# --> 140         parts.append(get_all_edges(handoff, agent, visited))
#     142 if not agent.handoffs and not isinstance(agent, Tool):  # type: ignore
#     143     parts.append(f'"{agent.name}" -> "__end__";')
#
# File ~/dev/license-to-play/.venv/lib/python3.13/site-packages/agents/extensions/visualization.py:142, in get_all_edges(agent, parent, visited)
#     138         parts.append(f"""
#     139         "{agent.name}" -> "{handoff.name}";""")
#     140         parts.append(get_all_edges(handoff, agent, visited))
# --> 142 if not agent.handoffs and not isinstance(agent, Tool):  # type: ignore
#     143     parts.append(f'"{agent.name}" -> "__end__";')
#     145 return "".join(parts)
#
# File ~/.local/share/uv/python/cpython-3.13.9-macos-aarch64-none/lib/python3.13/typing.py:1787, in _UnionGenericAlias.__instancecheck__(self, obj)
#    1785 def __instancecheck__(self, obj):
#    1786     for arg in self.__args__:
# -> 1787         if isinstance(obj, arg):
#    1788             return True
#    1789     return False
#
# File ~/.local/share/uv/python/cpython-3.13.9-macos-aarch64-none/lib/python3.13/typing.py:1375, in _BaseGenericAlias.__instancecheck__(self, obj)
#    1374 def __instancecheck__(self, obj):
# -> 1375     return self.__subclasscheck__(type(obj))
#
# File ~/.local/share/uv/python/cpython-3.13.9-macos-aarch64-none/lib/python3.13/typing.py:1378, in _BaseGenericAlias.__subclasscheck__(self, cls)
#    1377 def __subclasscheck__(self, cls):
# -> 1378     raise TypeError("Subscripted generics cannot be used with"
#    1379                     " class and instance checks")
#
# TypeError: Subscripted generics cannot be used with class and instance checks
