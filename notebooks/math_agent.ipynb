# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from IPython.display import Image, display
from langchain_openai import ChatOpenAI

from lg_deep_agent import math_agent
from lg_deep_agent.config import DEFAULT_AGENT_MODEL

llm = ChatOpenAI(model=DEFAULT_AGENT_MODEL)
agent = math_agent.create_agent(llm)

display(Image(agent.get_graph(xray=True).draw_mermaid_png()))

# %%
from langchain_core.messages import HumanMessage

from lg_deep_agent.utils.notebooks_utils import format_messages

messages = [HumanMessage(content="Add 3 and 4, then multiply by 2 and divide by 5")]

result = agent.invoke({"messages": messages})

format_messages(result["messages"])
# Out:
# ╭─────────────────────────────────────────────────── 🧑 Human ────────────────────────────────────────────────────╮
# │ Add 3 and 4, then multiply by 2 and divide by 5                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │ 🔧 Tool Call: add                                                                                               │
# │    Args: {                                                                                                      │
# ...
